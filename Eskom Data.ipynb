# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/My Drive
# Out:
# Mounted at /content/drive
# /content/drive/My Drive

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df_eskom = pd.read_csv('/content/drive/MyDrive/SACAIR-Hackathon-2023-<YOUR_TEAM_NAME>/Data/EskomData.csv')
df_eskom.describe()
# Out:
#        Original_Res_Forecast_before_Lockdown  Residual_Forecast  \
# count                           24336.000000       52608.000000
# mean                            25694.597880       24343.774945
# std                              2972.670983        2956.183187
# min                             17962.121000       14319.140000
# 25%                             23178.781250       21971.665000
# 50%                             25974.983500       24546.470000
# 75%                             27766.467750       26446.182500
# max                             34900.376000       34895.850000
#
#        RSA_Contracted_Forecast  Dispatchable_Generation  Residual_Demand  \
# count             52608.000000             49296.000000     49296.000000
# mean              25981.546915             23842.676404     24423.560193
# std                3220.293952              3080.577157      3022.830945
# min               15172.650000             13798.000000     13797.940000
# ...
